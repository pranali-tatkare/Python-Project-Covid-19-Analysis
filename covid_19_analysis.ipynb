# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Import Dataset**

# %%
data=pd.read_csv('covid_data.csv')

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %% [markdown]
# # **Explore the data**

# %%
#Top 5 records
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
#bottom 5 records
data.tail()
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
data.describe()
# Out:
#            Confirmed        Deaths      Recovered
# count     321.000000    321.000000     321.000000
# mean     9949.800623    709.152648    3030.277259
# std     31923.853086   3236.162817   14364.870365
# min         0.000000      0.000000       0.000000
# 25%       104.000000      2.000000       2.000000
# 50%       653.000000     12.000000      73.000000
# 75%      4655.000000    144.000000     587.000000
# max    299691.000000  27682.000000  132929.000000

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
#checking for null values
data.isnull()
# Out:
#       Date  State  Region  Confirmed  Deaths  Recovered
# 0    False   True   False      False   False      False
# 1    False   True   False      False   False      False
# 2    False   True   False      False   False      False
# 3    False   True   False      False   False      False
# 4    False   True   False      False   False      False
# ..     ...    ...     ...        ...     ...        ...
# 316  False  False   False      False   False      False
# 317  False  False   False      False   False      False
# 318  False  False   False      False   False      False
# 319  False  False   False      False   False      False
# 320  False  False   False      False   False      False
#
# [321 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
data.drop_duplicates()
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %% [markdown]
# # **Data visualization**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
# Distribution plot
sns.histplot(data['Region'], kde=True)
plt.show()

# %%
# Boxplot to check outliers
sns.boxplot(data['Deaths'])
plt.show()

# %%
data.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
#1 Show the number of confired , death and recovered cases in each region
data.groupby('Region').sum().head(5)
# Out:
#                   Date State  Confirmed  Deaths  Recovered
# Region
# Afghanistan  4/29/2020     0       1939      60        252
# Albania      4/29/2020     0        766      30        455
# Algeria      4/29/2020     0       3848     444       1702
# Andorra      4/29/2020     0        743      42        423
# Angola       4/29/2020     0         27       2          7

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %%
data.head(10)
# Out:
#         Date State               Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN          Afghanistan       1939      60        252
# 1  4/29/2020   NaN              Albania        766      30        455
# 2  4/29/2020   NaN              Algeria       3848     444       1702
# 3  4/29/2020   NaN              Andorra        743      42        423
# 4  4/29/2020   NaN               Angola         27       2          7
# 5  4/29/2020   NaN  Antigua and Barbuda         24       3         11
# 6  4/29/2020   NaN            Argentina       4285     214       1192
# 7  4/29/2020   NaN              Armenia       1932      30        900
# 8  4/29/2020   NaN              Austria      15402     580      12779
# 9  4/29/2020   NaN           Azerbaijan       1766      23       1267

# %%
#2.Remove all the record where confirmed cases less than 10
data[data.Confirmed <10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
#To remove the record satisfying particular condition
data1=data[~(data.Confirmed <10)]
data1
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
#3.In which region, maximum number of Death number were recorded
data.groupby('Region').Deaths.sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                60967
# Italy             27682
# UK                26165
# Spain             24275
# France            24121
# Belgium            7501
# Germany            6467
# Iran               5957
# Brazil             5513
# Netherlands        4727
# Mainland China     4633
# Canada             3154
# Turkey             3081
# Sweden             2462
# Mexico             1732
# Switzerland        1716
# Ireland            1190
# India              1079
# Portugal            973
# Russia              972
# Name: Deaths, dtype: int64

# %%
data.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
# 4. Check Latest Data by state
latest_data = data.sort_values('Date').groupby('State').tail(1)
print(latest_data[['State', 'Confirmed', 'Deaths', 'Recovered']])
# Out:
#                State  Confirmed  Deaths  Recovered
# 217        Greenland         11       0         11
# 215   Grand Princess         13       0          0
# 214        Gibraltar        141       0        131
# 213          Georgia      25775    1101          0
# 212            Gansu        139       2        137
# ..               ...        ...     ...        ...
# 264  New South Wales       3016      40       2284
# 263       New Mexico       3213     112          0
# 262       New Jersey     116365    6771          0
# 319           Yunnan        185       2        181
# 320         Zhejiang       1268       1       1263
#
# [137 rows x 4 columns]

# %%
# 5. Top 10 Countries with Highest Cases
top_cases = latest_data.sort_values(by='Confirmed', ascending=False).head(10)
plt.figure(figsize=(12,6))
sns.barplot(x='Confirmed', y='State', data=top_cases, palette='Reds_r')
plt.title('Top 10 State with Highest COVID-19 Cases')
plt.xlabel('Total Cases')
plt.ylabel('State')
plt.show()
# Out:
# <ipython-input-37-1405c1703801>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Confirmed', y='State', data=top_cases, palette='Reds_r')

# %%
data.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
# 6. Death Rate Calculation
latest_data['death_rate'] = (latest_data['Deaths'] / latest_data['Confirmed']) * 100
top_death_rate = latest_data.sort_values(by='death_rate', ascending=False).head(10)
print(top_death_rate[['State', 'death_rate']])
# Out:
#                             State  death_rate
# 203  Diamond Princess cruise ship         inf
# 296                  Sint Maarten   17.333333
# 194        British Virgin Islands   16.666667
# 270      Northern Mariana Islands   14.285714
# 256                    Montserrat    9.090909
# 251                      Michigan    9.084383
# 306      Turks and Caicos Islands    8.333333
# 200                   Connecticut    8.103261
# 218                    Guadeloupe    8.053691
# 247                    Martinique    8.000000

# %%
# 7. Plot Death Rate Top 10
plt.figure(figsize=(12,6))
sns.barplot(x='death_rate', y='State', data=top_death_rate, palette='Blues_r')
plt.title('Top 10 State with Highest COVID-19 Death Rate (%)')
plt.xlabel('Death Rate (%)')
plt.ylabel('State')
plt.show()
# Out:
# <ipython-input-41-340bdae45bb7>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='death_rate', y='State', data=top_death_rate, palette='Blues_r')

# %%
data.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
# 8. Recovered case Analysis
if 'Recovered' in data.columns:
    vaccinated = latest_data[['State', 'Recovered']].sort_values(by='Recovered', ascending=False).head(10)
    plt.figure(figsize=(12,6))
    sns.barplot(x='Recovered', y='State', data=vaccinated, palette='Greens_r')
    plt.title('Top 10 State by recovered case People')
    plt.xlabel('Recovered')
    plt.ylabel('State')
    plt.show()
# Out:
# <ipython-input-45-fe4232eea318>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Recovered', y='State', data=vaccinated, palette='Greens_r')

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]
